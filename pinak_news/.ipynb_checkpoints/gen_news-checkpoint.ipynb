# %%
import os

from datetime import datetime

import pandas as pd
import newspaper

from PIL import Image, ImageFont, ImageDraw 
import textwrap

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

from transformers import pipeline

import warnings
warnings.filterwarnings('ignore')

# Download necessary NLTK resources
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')



# Run date
current_date = datetime.now().date()
print("Current date:", current_date)

url_list = ['https://www.businesstoday.in',
            'https://www.financialexpress.com',
            'https://www.moneycontrol.com/stocksmarketsindia/']

print(url_list)

# Create new dirs
if not os.path.exists('news_data/{}'.format(current_date)):
    os.mkdir('news_data/{}'.format(current_date))
    
if not os.path.exists('images/{}'.format(current_date)):
    os.mkdir('images/{}'.format(current_date))
    
print(newspaper.hot())
# Out:
# [nltk_data] Downloading package stopwords to /Users/aman/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/aman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/aman/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/aman/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/aman/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Current date: 2023-07-21
# ['https://www.businesstoday.in', 'https://www.financialexpress.com', 'https://www.moneycontrol.com/stocksmarketsindia/']
# ['Powerball', "Women's World Cup 2023 groups", 'Kevin Mitnick', 'Sweet Magnolias', 'G Herbo', 'Jordan Addison', 'Rory McIlroy', 'Diablo 4 Season 1', 'Robert F. Kennedy Jr', 'Justin Thomas', 'Premios Juventud 2023', 'USWNT', 'Nigeria vs Canada', 'Matthew McConaughey', 'Dwight Howard', 'Mayans M.C', 'Washington Commanders', 'Rickie Fowler', 'FedNow', 'Henry Kissinger']

# %%
## Method definition
def extract_articles(article):
    try:
        article.download()
        article.parse()
        article.nlp()
        news.append(link + "~|~" + article.url + "~|~" + article.title + "~|~" + str(article.publish_date) + "~|~" + article.summary + "~|~" + str(article.keywords) + "~|~" + article.text)            
    except:
        print('issue in article')
        pass
    return news



def dump_articles(i, news):
    data = [row.split("~|~") for row in news]
    df = pd.DataFrame(data)
    df.columns = ["source", "link", "title", "publish_date", "summary", "keywords", "desc"]
    df.to_csv('news_data/{}/{}_news_articles.csv'.format(current_date, i), index=False)
    #updated_df = pd.read_csv('/news_data/{}/news_articles.csv'.format(current_date)).append(df, ignore_index=True)
    #updated_df.to_csv('/news_data/{}/news_articles.csv'.format(current_date), index=False)
    
    
    
    
for index, link in enumerate(url_list):
    print(f"Index: {index}, Url: {link}")
    
    news = []
    paper = newspaper.build(link, 
                            language='en', 
                            memoize_articles=True,
                            fetch_images=False)
    
    print('paper size: ', paper.size())
    
    for category_urls in paper.category_urls():
        print('category_urls: ' + category_urls)
        url = newspaper.build(category_urls, language='en', memoize_articles=True)
        
        if index == 0:
            for article in url.articles:
                if str(current_date) in article.url:
                    #print(article.url)
                    extract_articles(article)
                    
        elif index == 1:
            for article in url.articles[:20]:
                extract_articles(article)
            
        elif index == 2:
            for article in paper.articles:
                if article.url.count('-') > 2:
                    if "https://gujarati.moneycontrol.com" not in article.url:
                        if ".html" in article.url:
                            extract_articles(article)
                        
    if news:
        dump_articles(index, news)
    else:
        print("No news articles found")
# Out:
# Index: 0, Url: https://www.businesstoday.in
# paper size:  544
# category_urls: https://www.businesstoday.in
# category_urls: https://www.businesstoday.in/bt-tv
# category_urls: https://bazaar.businesstoday.in
# category_urls: https://www.businesstoday.in/visualstories
# category_urls: https://www.businesstoday.in/photos
# category_urls: https://www.businesstoday.in/indices
# category_urls: https://www.businesstoday.in/partners
# category_urls: https://www.businesstoday.in/auto
# category_urls: https://www.businesstoday.in/latest
# category_urls: https://www.businesstoday.in/coronavirus
# category_urls: https://www.businesstoday.in/magazine
# category_urls: https://www.businesstoday.in/education
# category_urls: https://www.businesstoday.in/markets
# category_urls: https://www.businesstoday.in/lifestyle
# category_urls: https://www.businesstoday.in/short-videos
# category_urls: https://www.businesstoday.in
# category_urls: https://www.businesstoday.in/trending
# category_urls: https://www.businesstoday.in/opinion
# category_urls: https://www.businesstoday.in/topic
# category_urls: https://www.businesstoday.in/industry
# category_urls: https://www.businesstoday.in/prnewswire
# Index: 1, Url: https://www.financialexpress.com
# paper size:  286
# category_urls: https://www.financialexpress.com
# category_urls: https://www.financialexpress.com/defence
# category_urls: https://www.financialexpress.com/market
# category_urls: https://www.financialexpress.com
# category_urls: https://www.financialexpress.com/photos
# category_urls: https://www.financialexpress.com/auto
# category_urls: https://www.financialexpress.com/education-2
# category_urls: https://epaper.financialexpress.com
# category_urls: https://hindi.financialexpress.com
# category_urls: https://www.financialexpress.com/economy
# category_urls: https://www.financialexpress.com/entertainment
# category_urls: https://www.financialexpress.com/lifestyle
# category_urls: https://www.financialexpress.com/opinion
# category_urls: https://www.financialexpress.com/world-news
# category_urls: https://www.financialexpress.com/videos
# category_urls: https://www.financialexpress.com/industry
# category_urls: https://www.financialexpress.com/india-news
# category_urls: https://www.financialexpress.com/brandwagon
# category_urls: https://www.financialexpress.com/sports
# category_urls: https://www.financialexpress.com/money
# category_urls: https://www.financialexpress.com/web-stories
# category_urls: https://financialexpress.com
# Index: 2, Url: https://www.moneycontrol.com/stocksmarketsindia/
# paper size:  506
# category_urls: https://www.moneycontrol.com/stocksmarketsindia/
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: https://hindi.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: http://www.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: https://gujarati.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: https://moneybhai.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: https://mmb.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: https://www.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# category_urls: https://images.moneycontrol.com
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article
# issue in article

# %% [markdown]
# ### Clean the news

# %%
# Read today's collected news
directory_path = 'news_data/{}'.format(current_date)
csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

dataframes = []

for file in csv_files:
    file_path = os.path.join(directory_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)
print(combined_df.shape)
print(combined_df.head())

news = combined_df



# Clean the news - drop dups, filter
news = news.dropna()

news['dt'] = news['publish_date'].str.slice(0, 10)
news.drop(columns='publish_date', inplace=True)
news.rename(columns={'dt': 'publish_date'}, inplace=True)

news = news[["source", "link", "title", "publish_date", "summary", "keywords", "desc"]]
news['publish_date'] = news['publish_date'].fillna(str(current_date))
news['publish_date'] = news['publish_date'].replace('None', str(current_date))

print(news['source'].unique())
print(news.shape)
news.to_csv('news_clean.csv', index=False)
# Out:
# (2600, 7)
#                                              source  \
# 0  https://www.moneycontrol.com/stocksmarketsindia/
# 1  https://www.moneycontrol.com/stocksmarketsindia/
# 2  https://www.moneycontrol.com/stocksmarketsindia/
# 3  https://www.moneycontrol.com/stocksmarketsindia/
# 4  https://www.moneycontrol.com/stocksmarketsindia/
#
#                                                 link  \
# 0  https://www.moneycontrol.com/news/business/mar...
# 1  https://www.moneycontrol.com/news/business/sto...
# 2  https://www.moneycontrol.com/news/business/ipo...
# 3  https://www.moneycontrol.com/news/business/sto...
# 4  https://www.moneycontrol.com/news/photos/busin...
#
#                                                title  \
# 0  Stock Market LIVE Updates: Nifty below 19,800 ...
# 1  Derivatives Outlook | What Should Be the Optio...
# 2  Utkarsh Small Finance Bank to debut on July 21...
# 3  Hot Stocks | Bet on HDFC AMC, Century Textiles...
# 4  Buzzing Stocks: RIL, HUL, Infosys, L&T, LTIMin...
#
#                 publish_date  \
# 0  2023-07-21 07:27:14+05:30
# 1  2023-07-20 16:32:10+05:30
# 2  2023-07-20 14:33:44+05:30
# 3  2023-07-21 06:36:03+05:30
# 4  2023-07-21 08:02:59+05:30
#
#                                              summary  \
# 0  July 21, 2023 / 09:42 AM ISTEven though Nifty ...
# 1  India's most valued company, Reliance Industri...
# 2  Reasonable valuations, healthy financial perfo...
# 3  The momentum indicator RSI has sustained above...
# 4  7/19 Utkarsh Small Finance Bank: The small fin...
#
#                                             keywords  \
# 0  ['infosys', 'volume', 'live', 'stock', 'openin...
# 1  ['implied', 'volatility', 'options', 'iv', 'in...
# 2  ['strong', 'bank', 'issue', 'rs', 'stellar', '...
# 3  ['momentum', 'pattern', 'returns', 'rs', 'brea...
# 4  ['hal', 'rs', 'profit', 'utkarsh', 'ril', 'tod...
#
#                                                 desc
# 0  July 21, 2023 / 09:42 AM IST\n\nEven though Ni...
# 1  Reliance industries Q1 result for FY24 is set ...
# 2  Reasonable valuations, healthy financial perfo...
# 3  Stocks\n\nlive bse live\n\nnse live Volume Tod...
# 4  1/19 Results on July 21: Reliance Industries, ...
# ['https://www.moneycontrol.com/stocksmarketsindia/'
#  'https://www.financialexpress.com' 'https://www.businesstoday.in']
# (1971, 7)

# %% [markdown]
# ### Select top random news articles

# %%
df = pd.read_csv('news_clean.csv').drop_duplicates(subset=['title'])
print(df.groupby('source').count())

#print(df['source'].unique())
#print(df['publish_date'].unique())
#print(df.groupby('publish_date').count())

df = df[df['publish_date'] == str(current_date)]

df['summary'] = df['summary'].str.strip()
df['title'] = df['title'].str.strip()
df = df[df['summary'].str.len() >= 400]
df = df[df['summary'].str.len() <= 1000]

#df = df[df['desc'].str.len() <= 3000]

sample_size_per_group = 30
def take_sample(group):
    return group.sample(n=min(sample_size_per_group, len(group)))

df = df.groupby('source', group_keys=False).apply(take_sample)


print(df.shape)
#print(df['source'].unique())
print(df.groupby('publish_date').count())
df[['publish_date', 'title', 'summary']]
# Out:
#                                                   link  title  publish_date  \
# source
# https://www.businesstoday.in                        16     16            16
# https://www.financialexpress.com                    23     23            23
# 21    निफ्टी के लिए पहला रजिस्टेंस 19981-20021/20046...
# 200   The G20 expert panel report says that MDBs and...
# 6     He believes the trend for the index is positiv...
# 3     The momentum indicator RSI has sustained above...
# 88    South Indian cities Bengaluru, Chennai and Hyd...
# 120   BJP charges opposition with not allowing discu...
# 86    While PhonePe is a market leader in unified pa...
# 143   Also, the flows into fixed income are likely t...
# 113   Shilpa Shetty shared a funny video on the risi...
# 0     July 21, 2023 / 09:42 AM ISTEven though Nifty ...
# 78    Govern and elections would take care of themse...
# 52    chemicalPRO Only Highlights- Quarterly perform...
# 7     The benchmark indices ended at a new record cl...
# 17    "Nifty continues to exhibit robust momentum, t...
# 112   Several Jaipur residents shared dramatic video...
# 51    The question that beckons an answer is whether...
# 60    current-affairs Live: Infosys Q1 Earnings | Ki...
# 85    Indiabulls Housing is at the top of the heap, ...

# %% [markdown]
# ## Generate images

# %%
from PIL import Image, ImageFont, ImageDraw 

df = df.reset_index(drop=True)

my_image = Image.open("res/news_bg.jpg").resize((1080, 1350))

for index, row in df.iterrows():
    # Create a copy of the original image and an ImageDraw object
    modified_image = my_image.copy()
    x, y = modified_image.size
    draw = ImageDraw.Draw(modified_image)
    
    # Pinaka
    #draw.rectangle((330, 0, 750, 80), fill='black', width=5)
    pinaka = 'Pinaka News'
    textwidth, textheight = draw.textsize(pinaka, font=ImageFont.truetype('fonts/EnglishTowne.ttf', 75))
    draw.text((x/2-textwidth/2,0), pinaka, fill='black', font=ImageFont.truetype('fonts/EnglishTowne.ttf', 75))
    
    # Parallel lines
    draw.line([(80,100), (1000, 100)], fill='black', width=3)
    draw.text((120,110), str(df['publish_date'][index][:10]), fill='black', font=ImageFont.truetype('fonts/times.ttf', 35))
    draw.text((460,110), '@pinakanews', fill='black', font=ImageFont.truetype('fonts/times.ttf', 35))
    draw.text((850,110), '#Fintech', fill='black', font=ImageFont.truetype('fonts/times.ttf', 35))
    draw.line([(80,160), (1000, 160)], fill='black', width=3)
    
    # textbox
    draw.rectangle((80, 190, 1000, 1260), outline='darkgray', width=5)
    
    # title
    title = textwrap.fill(text= str(df['title'][index]), width=40)
    textwidth, textheight = draw.textsize(title, font=ImageFont.truetype('fonts/times.ttf', 48))
    draw.text((x/2-textwidth/2,200), title, fill='darkslategray', font=ImageFont.truetype('fonts/times.ttf', 48))
    
    # Summary
    summary = textwrap.fill(text=str(df['summary'][index]), width=40) #.replace(".", ".\n")
    textwidth, textheight = draw.textsize(title, font=ImageFont.truetype('fonts/times.ttf', 48))
    draw.text((x/2-textwidth/2,400), summary, fill='black', font=ImageFont.truetype('fonts/times.ttf', 48))
    
    # Footer
    #draw.line([(90,1270), (990,1270)], fill='black', width=3)
    draw.rectangle((330, 1280, 750, 1380), fill='black', width=5)
    
    yana = 'Yet another news aggregator'
    textwidth, textheight = draw.textsize(yana, font=ImageFont.truetype('fonts/Sacramento-Regular.ttf', 45))
    draw.text((x/2-textwidth/2,1280), yana, fill='white', font=ImageFont.truetype('fonts/Sacramento-Regular.ttf', 45))
    
    # write images
    modified_image.save("images/{}/result_{}_{}.jpg".format(current_date, current_date, index))
    
print('post generation done')




# Display each image
modified_image.show()    
from IPython.display import Image, display
for num in range(5):
    display(Image(filename='images/{}/result_{}_{}.jpg'.format(current_date, current_date, num)))
# Out:
# post generation done

# %% [markdown]
# ## AI to generate heading and description

# %%
# Read today's collected news
directory_path = 'news_data/{}'.format(current_date)
csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

dataframes = []

for file in csv_files:
    file_path = os.path.join(directory_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)
print(combined_df.shape)

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)  
pd.set_option('display.max_colwidth', 25)
print(combined_df.groupby('source').count())


news = combined_df

# Clean the news - drop dups, filter
news = news.dropna()
print(news.shape)
print(news.groupby('source').count())

news['dt'] = news['publish_date'].str.slice(0, 10)
news.drop(columns='publish_date', inplace=True)
news.rename(columns={'dt': 'publish_date'}, inplace=True)

news = news[["source", "link", "title", "publish_date", "summary", "keywords", "desc"]]
news['publish_date'] = news['publish_date'].fillna(str(current_date))
news['publish_date'] = news['publish_date'].replace('None', str(current_date))

print(news.shape)
print(news.groupby('source').count())
news[["source", "title", "summary", "desc"]]

news['summary'] = news['summary'].str.strip()
news['title'] = news['title'].str.strip()
news = news[news['summary'].str.len() >= 500]
# Out:
# (2600, 7)
#                            link  title  publish_date  summary  keywords  desc
# source
# https://www.businessto...    20     20            20       16        20    16
# https://www.financiale...    60     60            60       51        60    51
# https://www.moneycontr...  2520   2520          2520     1904      2520  1904
# (1971, 7)
#                            link  title  publish_date  summary  keywords  desc
# source
# https://www.businessto...    16     16            16       16        16    16
# https://www.financiale...    51     51            51       51        51    51
# https://www.moneycontr...  1904   1904          1904     1904      1904  1904
# (1971, 7)
#                            link  title  publish_date  summary  keywords  desc
# source
# https://www.businessto...    16     16            16       16        16    16
# https://www.financiale...    51     51            51       51        51    51
# https://www.moneycontr...  1904   1904          1904     1904      1904  1904

# %%
#!pip install transformers
#!pip install bert-extractive-summarizer
#!pip install spacy

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest


nlp = spacy.load('en_core_web_sm')
doc = nlp(df['desc'][0])
df['desc'][0]

len(list(doc.sents))

keyword = []
stopwords = list(STOP_WORDS)
pos_tag = ['PROPN', 'ADJ', 'NOUN', 'VERB']
for token in doc:
    if(token.text in stopwords or token.text in punctuation):
        continue
    if(token.pos_ in pos_tag):
        keyword.append(token.text)
        
freq_word = Counter(keyword)
print(freq_word.most_common(5))
type(freq_word)

max_freq = Counter(keyword).most_common(1)[0][1]
for word in freq_word.keys():  
        freq_word[word] = (freq_word[word]/max_freq)
freq_word.most_common(5)

sent_strength={}
for sent in doc.sents:
    for word in sent:
        if word.text in freq_word.keys():
            if sent in sent_strength.keys():
                sent_strength[sent]+=freq_word[word.text]
            else:
                sent_strength[sent]=freq_word[word.text]
print(sent_strength)

print('')
summarized_sentences = nlargest(3, sent_strength, key=sent_strength.get)
print(summarized_sentences)

print(type(summarized_sentences[0]))

final_sentences = [ w.text for w in summarized_sentences ]
summary = ' '.join(final_sentences)
print(summary)
# Out:
# [('cent', 12), ('stock', 10), ('growth', 8), ('Infosys', 7), ('revenue', 7)]
# {Shares of Infosys took a beating on Friday morning, plunging over 9 per cent as a host of brokerages cut their share price targets on the stock following a downward revision FY24 revenue guidance.: 5.416666666666666, The fall was much in line with a steep fall in Infosys American Depositary Receipts (ADRs) overnight.: 2.4166666666666665, The stock fell after the IT giant revised downward its FY24 constant currency (CC) revenue guidance to 1-3.5 per cent compared with 4-7 per cent suggested earlier.: 5.25, This is even as its CC growth for Q1 came in line with Street estimates.: 1.75, Infosys cited lower-than-expected volumes and discretionary spending, delays in decision-making and push-outs in anticipated mega deals.
#
# : 2.166666666666666, "The stock has run up by 19 per cent from its recent lows in April and is currently trading at 22 times one year forward PE, close to its five-year average (22x).: 3.666666666666667, We believe stock can remain under pressure in the near term until clarity emerges on revenue growth revival.: 2.7499999999999996, We downgrade to Neutral from BUY," said Philip Capital.
#
# : 1.0, The stock fell 9.47 per cent to hit a low of Rs 1,311.60 on BSE.: 2.666666666666667, Infosys ADRs plunged 8.41 per cent to $16.22 apiece in overnight trading and were down another 0.7 per cent in the after hours.: 3.3333333333333335, The steep fall in ADRs is reminding investors of a similar fall in Infosys ADRs in April following surprisingly weak March quarter results.: 3.166666666666667, That time, Infosys saw a double-digit percentage fall and was battered badly on the domestic market the next day.
#
# : 1.8333333333333335, A sudden sharp cut in revenue growth guidance in 1QFY24 is surprising for a company at the top of the game and leading growth charts, Kotak Institutional Equities said.
#
# : 3.8333333333333344, "This does warrant a closer scrutiny although there is nothing in metrics that suggests loss of competitiveness or wallet share.: 0.8333333333333333, We cut FY2024-26E revenue forecast by 2-3 per cent and FY24 CC revenue growth forecast to 3.3 per cent from 4.9 per cent earlier.: 6.333333333333334, We cut EPS estimates by 2-3% baking in lower growth and marginal cut in margins, offset by change in INR/USD assumption," it said.
#
# : 3.7500000000000004, Nomura India said the IT firm is set to underperform industry growth in FY24F. It has downgraded the stock to 'Reduce' while suggesting a target of Rs 1,210 from 1,450.
#
# : 4.0, "We lower FY24-25F earnings by 3-4 per cent driven by revenue estimates.: 2.9166666666666665, Our revised EPS estimates are 5-6 per cent lower than the Street’s.: 2.4999999999999996, We downgrade the stock to Reduce from Neutral, with a lower target price of Rs 1,210 set at an unchanged 18 times FY25F EPS.: 3.8333333333333335, Our target multiple is based on a three-stage growth model discussed in our sector report and is lower than the five-year average of 20 times.: 2.833333333333333, The stock currently trades at 21.7 times FY25F EPS," the brokerage said.
#
# : 2.25, Macquarie has downgraded the stock to 'Underperform' with a target of Rs 1,130.: 1.9166666666666667, BofA Securities finds the stock Rs 1,390 worthy.
#
# : 1.5833333333333335, Also read: Reliance Industries, Infosys, LIC, Tech Mahindra, HUL, Ashok Leyland, others among stocks to watch on July 21, 2023
#
# Also read: Stocks that market analysts recommended on July 21, 2023:: 2.4999999999999996, Titagarh Rail Systems, Polycab India, Bank of Maharashtra, VRL Logistics: 0.8333333333333335}
#
# [We cut FY2024-26E revenue forecast by 2-3 per cent and FY24 CC revenue growth forecast to 3.3 per cent from 4.9 per cent earlier., Shares of Infosys took a beating on Friday morning, plunging over 9 per cent as a host of brokerages cut their share price targets on the stock following a downward revision FY24 revenue guidance., The stock fell after the IT giant revised downward its FY24 constant currency (CC) revenue guidance to 1-3.5 per cent compared with 4-7 per cent suggested earlier.]
# <class 'spacy.tokens.span.Span'>
# We cut FY2024-26E revenue forecast by 2-3 per cent and FY24 CC revenue growth forecast to 3.3 per cent from 4.9 per cent earlier. Shares of Infosys took a beating on Friday morning, plunging over 9 per cent as a host of brokerages cut their share price targets on the stock following a downward revision FY24 revenue guidance. The stock fell after the IT giant revised downward its FY24 constant currency (CC) revenue guidance to 1-3.5 per cent compared with 4-7 per cent suggested earlier.

# %%
import spacy
from gensim.models import TfidfModel
from gensim.corpora import Dictionary
from gensim.similarities import MatrixSimilarity

def preprocess(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    return sentences

def summarize(text, num_sentences=2):
    sentences = preprocess(text)
    dictionary = Dictionary([sentence.split() for sentence in sentences])
    corpus = [dictionary.doc2bow(sentence.split()) for sentence in sentences]
    
    tfidf = TfidfModel(corpus)
    tfidf_corpus = tfidf[corpus]
    
    similarity_matrix = MatrixSimilarity(tfidf_corpus)
    
    query = dictionary.doc2bow(text.split())
    query_tfidf = tfidf[query]
    
    similarities = similarity_matrix[query_tfidf]
    ranked_sentences = sorted(enumerate(similarities), key=lambda item: -item[1])
    
    summary_indices = [idx for idx, _ in ranked_sentences[:num_sentences]]
    summary = [sentences[idx] for idx in sorted(summary_indices)]
    
    return " ".join(summary)



#summary = summarize(df['desc'][1], num_sentences=2)
#print('summary: ' + summary )

df['GPT2_AI'] = df['desc'].apply(summarize)
df[['GPT2_AI']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 38
#      31     return " ".join(summary)
#      35 #summary = summarize(df['desc'][1], num_sentences=2)
#      36 #print('summary: ' + summary )
# ---> 38 df['GPT2_AI'] = df['desc'].apply(summarize)
#      39 df[['GPT2_AI']]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[13], line 20, in summarize(text, num_sentences)
#      17 tfidf = TfidfModel(corpus)
#      18 tfidf_corpus = tfidf[corpus]
# ---> 20 similarity_matrix = MatrixSimilarity(tfidf_corpus)
#      22 query = dictionary.doc2bow(text.split())
#      23 query_tfidf = tfidf[query]
#
# File ~/anaconda3/lib/python3.10/site-packages/gensim/similarities/docsim.py:813, in MatrixSimilarity.__init__(self, corpus, num_best, dtype, num_features, chunksize, corpus_len)
#     811 if corpus is not None:
#     812     if self.num_features <= 0:
# --> 813         raise ValueError(
#     814             "cannot index a corpus with zero features (you must specify either `num_features` "
#     815             "or a non-empty corpus in the constructor)"
#     816         )
#     817     logger.info("creating matrix with %i documents and %i features", corpus_len, num_features)
#     818     self.index = numpy.empty(shape=(corpus_len, num_features), dtype=dtype)
#
# ValueError: cannot index a corpus with zero features (you must specify either `num_features` or a non-empty corpus in the constructor)

# %%
# Function to generate GPT2_text
def gpt2(text):
    generator = pipeline(task='text-generation',  model='gpt2-medium')
    gpt_text = generator(text, max_length=1000, do_sample=True, temperature=0.7, num_return_sequences=1)
    return gpt_text[0]['generated_text']

df['GPT2_AI'] = df['desc'][:1000].apply(gpt2)
df[['GPT2_AI']]
